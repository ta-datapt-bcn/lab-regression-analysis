# %% [markdown]
# # Lab: Regression Analysis

# %% [markdown]
# ### Before you start:
#
# * Read the README.md file
# * Comment as much as you can and use the resources (README.md file)
#
# Happy learning!

# %% [markdown]
# ## Challenge 1
# I work at a coding bootcamp, and I have developed a theory that the younger my students are, the more often they are late to class. In order to test my hypothesis, I have collected some data in the following table:
#
# | StudentID | Age | Tardies |
# |--------|-----|------------|
# | 1      | 17  | 10         |
# | 2      | 51  | 1          |
# | 3      | 27  | 5          |
# | 4      | 21  | 9         |
# | 5      | 36  |  4         |
# | 6      | 48  |  2         |
# | 7      | 19  |  9         |
# | 8      | 26  | 6          |
# | 9      | 54  |  0         |
# | 10     | 30  |  3         |

# %% [markdown]
# Use this command to create a dataframe with the data provided in the table.
# ~~~~
# student_data = pd.DataFrame({'X': [x_values], 'Y': [y_values]})
# ~~~~

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.linear_model import LinearRegression

# %%
# Your code here. 
student_data = pd.DataFrame({'x': [17,51,27,21,36,48,19,26,54,30], 'y': [10,1,5,9,4,2,9,6,0,3]})

# %%
student_data
# Out:
#     x   y
# 0  17  10
# 1  51   1
# 2  27   5
# 3  21   9
# 4  36   4
# 5  48   2
# 6  19   9
# 7  26   6
# 8  54   0
# 9  30   3

# %% [markdown]
# Draw a dispersion diagram (scatter plot) for the data.

# %%
plt.rcParams['figure.figsize'] = (12,8)
#_= sns.regplot(data=student_data, x='x', y='y', kind='scatter', height=6, aspect=1.5)
_=plt.scatter(data=student_data, x='x', y='y')

# %% [markdown]
# Do you see a trend? Can you make any hypotheses about the relationship between age and number of tardies?

# %% [raw]
# El número de veces que un alumno llega tarde es inversamente proporcional a su edad.

# %% [markdown]
# Calculate the covariance and correlation of the variables in your plot. What is the difference between these two measures? Compare their values. What do they tell you in this case? Add your responses as comments after your code.

# %%
student_data.cov()
# Out:
#             x          y
# x  187.655556 -45.566667
# y  -45.566667  12.544444

# %%
# Your response here.
student_data.corr()
# Out:
#           x         y
# x  1.000000 -0.939163
# y -0.939163  1.000000

# %% [markdown]
# Build a regression model for this data. What will be your outcome variable? What type of regression are you using? Add your responses as comments after your code.

# %%
stats.linregress(student_data['x'],student_data['y'])
# Out:
# LinregressResult(slope=-0.24282077091598084, intercept=12.88880336313577, rvalue=-0.9391626886887123, pvalue=5.56665383455336e-05, stderr=0.03139728816158602)

# %%
# Hacemos la ecuación del predictor

def linreg(x):
    a = stats.linregress(student_data['x'],student_data['y'])[0]
    b = stats.linregress(student_data['x'],student_data['y'])[1]
    return a*x + b

# %% [markdown]
# Plot your regression model on your scatter plot.

# %%
# Vemos que coincide con la automáticamente dibujada por regplot

_=sns.regplot(data=student_data, x='x', y='y')
_=plt.plot(np.arange(10,60,1), linreg(np.arange(10,60,1)), color='red', linestyle=':')

# %% [markdown]
# ##### OTRA OPCIÓN CON STATSMODELS

# %%
import statsmodels.api as sm

# %%
X = sm.add_constant(student_data['x'])
y = student_data['y']
model = sm.OLS(y, X).fit()

# %%
model.summary()
# Out:
# /Users/borjatv/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/stats.py:1603: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.882
# Model:                            OLS   Adj. R-squared:                  0.867
# Method:                 Least Squares   F-statistic:                     59.81
# Date:                Mon, 24 May 2021   Prob (F-statistic):           5.57e-05
# Time:                        00:28:16   Log-Likelihood:                -15.622
# No. Observations:                  10   AIC:                             35.24
# Df Residuals:                       8   BIC:                             35.85
# Df Model:                           1
# Covariance Type:            nonrobust
# ...

# %%
model.predict()
# Out:
# array([ 8.76085026,  0.50494405,  6.33264255,  7.78956717,  4.14725561,
#         1.23340636,  8.27520872,  6.57546332, -0.22351827,  5.60418024])

# %%
# Vemos que también coincide con la automáticamente dibujada por regplot

_=sns.regplot(data=student_data, x='x', y='y')
_=plt.plot(student_data['x'],model.predict(), color='red', linestyle=':')

# %% [markdown]
# Interpret the results of your model. What can conclusions can you draw from your model and how confident in these conclusions are you? Can we say that age is a good predictor of tardiness? Add your responses as comments after your code.

# %% [raw]
# Hay una correlación negativa de -0.93, con lo cual hay bastante credibilidad a la hora de predecir datos con esta línea de regresión ya que es muy cercana a -1.

# %% [markdown]
# ## Challenge 2
# For the second part of this lab, we will use the vehicles.csv data set. You can find a copy of the dataset in the git hub folder. This dataset includes variables related to vehicle characteristics, including the model, make, and energy efficiency standards, as well as each car's CO2 emissions. As discussed in class the goal of this exercise is to predict vehicles' CO2 emissions based on several independent variables.

# %%
# Import any libraries you may need & the data
df = pd.read_csv('./vehicles.csv')

# %%
df.head(3)
# Out:
#          Make                Model  Year  Engine Displacement  Cylinders  \
# 0  AM General    DJ Po Vehicle 2WD  1984                  2.5        4.0
# 1  AM General     FJ8c Post Office  1984                  4.2        6.0
# 2  AM General  Post Office DJ5 2WD  1985                  2.5        4.0
#
#       Transmission        Drivetrain                Vehicle Class Fuel Type  \
# 0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 1  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 2  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD   Regular
#
#    Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0          19.388824        18           17            17
# 1          25.354615        13           13            13
# 2          20.600625        16           17            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# ...

# %% [markdown]
# Let's use the following variables for our analysis: Year, Cylinders, Fuel Barrels/Year, Combined MPG, and Fuel Cost/Year. We will use 'CO2 Emission Grams/Mile' as our outcome variable.
#
# Calculate the correlations between each of these variables and the outcome. Which variable do you think will be the most important in determining CO2 emissions? Which provides the least amount of helpful information for determining CO2 emissions? Add your responses as comments after your code.

# %%
dfco2 = df[['CO2 Emission Grams/Mile', 'Year', 'Cylinders', 'Fuel Barrels/Year', 'Combined MPG', 'Fuel Cost/Year']]

# %%
dfco2.corr()
# Out:
#                          CO2 Emission Grams/Mile      Year  Cylinders  \
# CO2 Emission Grams/Mile                 1.000000 -0.222300   0.752393
# Year                                   -0.222300  1.000000   0.082469
# Cylinders                               0.752393  0.082469   1.000000
# Fuel Barrels/Year                       0.986189 -0.221084   0.739517
# Combined MPG                           -0.926229  0.204751  -0.698648
# Fuel Cost/Year                          0.930865 -0.091913   0.778153
#
#                          Fuel Barrels/Year  Combined MPG  Fuel Cost/Year
# CO2 Emission Grams/Mile           0.986189     -0.926229        0.930865
# Year                             -0.221084      0.204751       -0.091913
# Cylinders                         0.739517     -0.698648        0.778153
# Fuel Barrels/Year                 1.000000     -0.909743        0.916208
# Combined MPG                     -0.909743      1.000000       -0.875185
# ...

# %%
# Your response here. 
plt.rcParams['figure.figsize'] = (12,8)
sns.heatmap(dfco2.corr(), cmap='Blues', annot=True)
# Out:
# <AxesSubplot:>

# %% [raw]
# La variable que más influirá a la hora de determinar las emisiones de CO2 será 'Fuel Barrels/Year', con la que tiene una correlación casi igual a 1. De todas formas, se supone que el número de barriles al año y la emisión de CO2 son variables prácticamente calculadas una a partir de la otra, representando quizás el 1% de diferencia en función del tipo de combustible que utilice el motor.
#
# La que menos influirá será el año porque es la menos correlacionada al ser su valor de correlación la más cercana a 0 (hay que coger la más cercana a 0 y no la menor porque si es cercana a -1, implica correlación negativa, lo cual nos da información a la hora de predecir).

# %% [markdown]
# Build a regression model for this data. What type of regression are you using? Add your responses as comments after your code.

# %%
sns.pairplot(dfco2)

# %% [raw]
# A pesar de que desde el punto de vista matemático las mayores correlaciones con el consumo de CO2 se muestran en las variables 'Fuel Barrels/Year' y 'Fuel Cost/Year', no creo que ninguna tenga relevancia ya que los 3 campos están relacionados, probablemente calculados uno a partir del otro, con lo cual no aporta demasiado en lo que se refiere a predicción.
#
# Elegí un modelo de regresión múltiple que predice el consumo de CO2 a partir de las variables 'Cylinders' y 'Combined MPG'.

# %%
lr = LinearRegression()
X = df[['Cylinders', 'Combined MPG']]
y = df['CO2 Emission Grams/Mile']
lr.fit(X, y).score(X,y)
# Out:
# 0.8795549346379934

# %% [markdown]
# Print your regression summary, and interpret the results. What are the most important varibles in your model and why? What can conclusions can you draw from your model and how confident in these conclusions are you? Add your responses as comments after your code.

# %%
sns.regplot(y, lr.predict(X))
# Out:
# /Users/borjatv/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='CO2 Emission Grams/Mile'>

# %%
# Your response here.

# %%
from scipy.optimize import curve_fit

# %%
def f(x,a,b,c):
    return a + b*x + c*x**2

# %%
x = df['Combined MPG']
y = df['CO2 Emission Grams/Mile']

# %%
curve_fit(f,x,y)
# Out:
# (array([ 1.28188760e+03, -5.71464498e+01,  7.85041011e-01]),
#  array([[ 1.55345270e+00, -1.35910197e-01,  2.76208806e-03],
#         [-1.35910197e-01,  1.23605751e-02, -2.60864787e-04],
#         [ 2.76208806e-03, -2.60864787e-04,  5.75641484e-06]]))

# %%
curve_fit(f,x,y)[0][0]
# Out:
# -57.14644979497731

# %%
help(plt.plot)
# Out:
# Help on function plot in module matplotlib.pyplot:
#
# plot(*args, scalex=True, scaley=True, data=None, **kwargs)
#     Plot y versus x as lines and/or markers.
#
#     Call signatures::
#
#         plot([x], y, [fmt], *, data=None, **kwargs)
#         plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
#     The coordinates of the points or line nodes are given by *x*, *y*.
#
#     The optional parameter *fmt* is a convenient way for defining basic
#     formatting like color, marker and linestyle. It's a shortcut string
#     notation described in the *Notes* section below.
#
#     >>> plot(x, y)        # plot x and y using default line style and color
#     >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
#     >>> plot(y)           # plot y using x as index array 0..N-1
#     >>> plot(y, 'r+')     # ditto, but with red plusses
#
#     You can use `.Line2D` properties as keyword arguments for more
# ...

# %%
plt.scatter(x,y)

plt.scatter(x, f(x, curve_fit(f,x,y)[0][0], curve_fit(f,x,y)[0][1], curve_fit(f,x,y)[0][2]), color='red')

# %% [markdown]
# ## Bonus Challenge: Error Analysis

# %% [markdown]
# I am suspicious about the last few parties I have thrown: it seems that the more people I invite the more people are unable to attend. To know if my hunch is supported by data, I have decided to do an analysis. I have collected my data in the table below, where X is the number of people I invited, and Y is the number of people who attended.
#
# |  X |  Y |
# |----|----|
# | 1  |  1 |
# | 3  |  2 |
# | 4  |  4 |
# | 6  |  4 |
# | 8  |  5 |
# | 9  |  7 |
# | 11 |  8 |
# | 14 |  13 |

# %% [markdown]
# We want to know if the relationship modeled by the two random variables is linear or not, and therefore if it is appropriate to model it with a linear regression.
# First, build a dataframe with the data.

# %%
# Your code here.
party = pd.DataFrame({'x': [1,3,4,6,8,9,11,14], 'y': [1,2,4,4,5,7,8,13]})

# %%
party.corr()
# Out:
#          x        y
# x  1.00000  0.96523
# y  0.96523  1.00000

# %% [markdown]
# Draw a dispersion diagram (scatter plot) for the data, and fit a regression line.

# %%
stats.linregress(party['x'],party['y'])
# Out:
# LinregressResult(slope=0.8484848484848485, intercept=-0.43939393939393945, rvalue=0.9652303546573691, pvalue=0.00010236374464090686, stderr=0.09380896778286217)

# %%
def linparty(x):
    a = stats.linregress(party['x'],party['y'])[0]
    b = stats.linregress(party['x'],party['y'])[1]
    return a*x + b

# %%
# Vemos que coincide con la automáticamente dibujada por regplot

_=sns.regplot(data=party, x='x', y='y')
_=plt.plot(np.arange(0,20,1), linparty(np.arange(0,20,1)), color='red', linestyle=':')

# %% [markdown]
# What do you see? What does this plot tell you about the likely relationship between the variables? Print the results from your regression.

# %% [raw]
# Hay una correlación positiva bastante evidente, a mayor número de invitados, mayor número de participantes que han acudido.
#
# Vamos a llevar a cabo el mismo ejercicio pero representando en el eje y el número de ausencias en lugar del número de invitados.

# %%
pty = pd.DataFrame({'x': [1,3,4,6,8,9,11,14], 'y': [0,1,0,2,3,2,3,1]})

# %%
pty.corr()
# Out:
#           x         y
# x  1.000000  0.550482
# y  0.550482  1.000000

# %%
stats.linregress(pty['x'],pty['y'])
# Out:
# LinregressResult(slope=0.15151515151515152, intercept=0.43939393939393945, rvalue=0.5504818825631803, pvalue=0.15740634710973236, stderr=0.09380896778286217)

# %%
def linpty(x):
    a = stats.linregress(pty['x'],pty['y'])[0]
    b = stats.linregress(pty['x'],pty['y'])[1]
    return a*x + b

# %%
_=sns.regplot(data=pty, x='x', y='y')
_=plt.plot(np.arange(0,20,1), linpty(np.arange(0,20,1)), color='red', linestyle=':')

# %% [markdown]
# Do you see any problematic points, or outliers, in your data? Remove these points and recalculate your regression. Print the new dispersion diagram with your new model and the results of your model.

# %%
# Construimos de nuevo el df quitando los 'outliers' que están fuera del intervalo de confianza

# Son los mismos en ambas líneas de regresión

pty = pd.DataFrame({'x': [1,3,6,9,11], 'y': [0,1,2,2,3]})

# %%
pty.corr()
# Out:
#          x        y
# x  1.00000  0.95723
# y  0.95723  1.00000

# %%
stats.linregress(pty['x'],pty['y'])
# Out:
# LinregressResult(slope=0.2647058823529412, intercept=0.0117647058823529, rvalue=0.9572301670759134, pvalue=0.010549556639648478, stderr=0.04619301564466568)

# %%
_=sns.regplot(data=pty, x='x', y='y')
_=plt.plot(np.arange(0,20,1), linpty(np.arange(0,20,1)), color='red', linestyle=':')

# %% [markdown]
# What changed? Based on the results of the two models and your graphs, what can you say about the form of the data with the problematic point and without it?

# %% [raw]
# La inclinación de la curva ha pasado de 0.15 a 0.26 porque la correlación es ahora mucho mayor, lo cual implica que se esperan más ausencias a mayor número de invitados.
